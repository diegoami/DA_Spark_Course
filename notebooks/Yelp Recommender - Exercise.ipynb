# %% [markdown]
# # Yelp Recommender
#
# ## Intro
#
# The purpose of this exercise is to use Spark in a real dataset, instead of just a toy example.
#
# You will use the data from the [Yelp Dataset Challenge](https://www.yelp.de/dataset_challenge), which contains information about businesses, users, reviews and more.
#
# For this exercise, you will need to focus only on the following files:
# - yelp_academic_dataset_business.json
# - yelp_academic_dataset_review.json
#
# The goal is to build a recommender using Spark's ALS (Alternating Least Squares) and then generate recommendations for a given user.
#
# Since the dataset is quite big, you should pick a business category (e.g. Restaurants) and a city (e.g. Edinburgh) and work on the recommender using only this subset of the data.
#
# Please take some time to:
# - find out what information you will need to feed as input to Spark's ALS
# - check how this information is available in the dataset
# - plan how you will tackle this problem

# %%
import pyspark
from pyspark import SparkContext, SQLContext


sc = pyspark.SparkContext('local[*]')
sqlc = SQLContext(sc)

# %%
people = sqlc.read.json("/media/diego/QData/datasets/yelp_dsr/yelp_academic_dataset_business.json")

# %%
type(people)
# Out:
# pyspark.sql.dataframe.DataFrame

# %% [markdown]
# ## Business Data
#
# - Load the file ***yelp_academic_dataset_business.json*** and select the following columns:
#     - business_id
#     - name
#     - city
#     - stars
#     - categories

# %%
people.createOrReplaceTempView("people")
toronto  = sqlc.sql("select * from people where city='Toronto'")

# %%
toronto.toPandas()
# Out:
#                                                  address  \
# 0                                     979 Bloor Street W
# 1                                      321 Jarvis Street
# 2                                    1000 Queen Street W
# 3                       123 Front St, Unit 103 and 103-A
# 4                                        1560 Queen St E
# 5                                    2014 Queen Street E
# 6                                      2816 Markham Road
# 7                                      250 Queens Quay W
# 8                                          1560 Yonge St
# 9                                    1034 Queen Street W
# 10                                   2075 Bayview Avenue
# 11                            201 Weston Road, Suite 101
# 12                                         5515 Yonge St
# 13                                         55 Bloor St W
# 14                                    561 Bloor Street W
# 15                                     5460 Yonge Street
# 16                               213 Roncesvalles Avenue
# 17                                 2555 Steeles Avenue W
# 18                                    150 Bloor Street W
# 19                                    922 Eglinton Ave W
# 20                                   510B Front Street W
# 21                                    80 Mitchell Avenue
# 22                                    6065 Steeles Ave E
# 23                                     1055 Yonge Street
# 24                                   1186 Queen Street W
# 25                                   2256 Queen Street E
# 26     Milliken Wellss Shopping Plaza, 250 Alton Towe...
# 27                                     13 Belmont Street
# 28             Kensington Market, 8 Saint Andrews Street
# 29                                     2761 Markham Road
# ...                                                  ...
# 14510                                57 Yorkville Avenue
# 14511                              1438 Gerrard Street E
# 14512                                  91 Bloor St. West
# 14513                                 167 Niagara Street
# 14514                               786 Broadview Avenue
# 14515                         31 Tapscott Road, Suite 29
# 14516                                 607 Queen Street W
# 14517                            121 Roncesvalles Avenue
# 14518                                   267 Danforth Ave
# 14519                                         55 Mill St
# 14520                                      449 Jarvis St
# 14521                                   2015 Avenue Road
# 14522                                 510 Queen Street W
# 14523                                       684 Yonge St
# 14524                                  4860 Yonge Street
# 14525                                  2360 Yonge Street
# 14526                                  1210 Kennedy Road
# 14527                                   2 Wheeler Avenue
# 14528                                       125 Peter St
# 14529                                 894 Queen Street E
# 14530                   263 Adelaide Street W, 4th Floor
# 14531                                  1835 Yonge Street
# 14532                                     563 Queen St W
# 14533                               1382 Danforth Avenue
# 14534                                 110 Eglinton Ave E
# 14535                                    558 Jane Street
# 14536                                   25 King Street W
# 14537                                 386 College Street
# 14538                                    28 Logan Avenue
# 14539                                    1210 Kennedy Rd
#
#                                               attributes  \
# 0      [Alcohol: none, Ambience: {'romantic': False, ...
# 1      [BusinessAcceptsCreditCards: True, Restaurants...
# 2      [BusinessAcceptsCreditCards: True, BusinessPar...
# 3      [Alcohol: none, Ambience: {'romantic': False, ...
# 4      [BusinessAcceptsCreditCards: False, BusinessPa...
# 5      [BusinessAcceptsCreditCards: True, GoodForKids...
# 6      [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 7      [Alcohol: beer_and_wine, BusinessAcceptsCredit...
# 8      [BikeParking: True, BusinessAcceptsCreditCards...
# 9      [AgesAllowed: 19plus, Ambience: {'romantic': F...
# 10                                                  None
# 11                    [BusinessAcceptsCreditCards: True]
# 12     [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 13     [BusinessAcceptsCreditCards: True, BusinessPar...
# 14     [Alcohol: beer_and_wine, BusinessAcceptsCredit...
# 15     [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 16     [BikeParking: True, BusinessAcceptsCreditCards...
# 17                                                  None
# 18     [BusinessAcceptsCreditCards: True, Restaurants...
# 19     [BusinessAcceptsCreditCards: True, BusinessPar...
# 20     [AcceptsInsurance: True, BusinessAcceptsCredit...
# 21               [BikeParking: True, GoodForKids: False]
# 22     [BusinessParking: {'garage': False, 'street': ...
# 23     [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 24     [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 25     [BikeParking: True, BusinessAcceptsCreditCards...
# 26     [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 27     [BusinessAcceptsCreditCards: False, BusinessPa...
# 28     [Alcohol: beer_and_wine, Ambience: {'romantic'...
# 29     [Alcohol: full_bar, Ambience: {'romantic': Fal...
# ...                                                  ...
# 14510  [BikeParking: False, BusinessAcceptsCreditCard...
# 14511  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 14512  [BusinessAcceptsCreditCards: True, BusinessPar...
# 14513  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 14514  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 14515  [BikeParking: True, BusinessAcceptsCreditCards...
# 14516  [Ambience: {'romantic': False, 'intimate': Fal...
# 14517  [BusinessParking: {'garage': False, 'street': ...
# 14518  [BikeParking: True, BusinessAcceptsCreditCards...
# 14519  [BusinessAcceptsCreditCards: True, BusinessPar...
# 14520  [Alcohol: full_bar, BestNights: {'monday': Fal...
# 14521  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 14522  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 14523  [BikeParking: True, BusinessAcceptsCreditCards...
# 14524  [Alcohol: beer_and_wine, Ambience: {'romantic'...
# 14525                                               None
# 14526  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 14527  [Alcohol: full_bar, BestNights: {'monday': Fal...
# 14528  [BusinessAcceptsCreditCards: True, ByAppointme...
# 14529  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 14530                      [WheelchairAccessible: False]
# 14531  [Alcohol: beer_and_wine, Ambience: {'romantic'...
# 14532  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 14533  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 14534  [BikeParking: True, BusinessAcceptsCreditCards...
# 14535  [Alcohol: none, BikeParking: True, BusinessAcc...
# 14536  [BusinessAcceptsCreditCards: True, BusinessPar...
# 14537  [BikeParking: True, BusinessAcceptsCreditCards...
# 14538  [Alcohol: none, Ambience: {'romantic': False, ...
# 14539  [Alcohol: full_bar, Ambience: {'romantic': Fal...
#
#                   business_id  \
# 0      EDqCEAGXVGCH4FJXgqtjqg
# 1      cdk-qqJ71q6P7TJTww_DSA
# 2      YCsLfBVdLFeN2Necw1HPSA
# 14510 -79.390415               Pusateri's Fine Foods
# 14511 -79.321834              Eulalie's Corner Store
# 14512 -79.390451                       MAC Cosmetics
# 14513 -79.406496                Old York Bar & Grill
# 14514 -79.358788                           Kobo Nobu
# 14515 -79.222253                Super One Hair Salon
# 14516 -79.402275                     Marwan Shawarma
# 14517 -79.447604                       Mrs. Huizenga
# 14518 -79.354637                            El Pipil
# 14519 -79.358025                   Cube Works Studio
# 14520 -79.377242                        Red Lion Pub
# 14521 -79.419779          Left Bank Grill & Wine Bar
# 14522 -79.401463                  Velvet Underground
# 14523 -79.385662          PCV Computer & Electronics
# 14524 -79.411510                               Kenzo
# 14525 -79.398965                           Sushi SHO
# 14526 -79.277105                       El Pulgarcito
# 14527 -79.299124                        Captain Jack
# 14528 -79.392966                    Let's Get Moving
# 14529 -79.343110                The Roy Public House
# 14530 -79.389590         Loft404 Inspired Gatherings
# 14531 -79.396128            I Zu Japanese Restaurant
# 14532 -79.400585       Hot Wings Grill and Rib House
# 14533 -79.328050                            The Wren
# 14534 -79.395304               Moores Clothing Store
# 14535 -79.490213     J&C Bistro - The Bistro on Jane
# 14536 -79.379512           Institut De Beaute Nimana
# 14537 -79.405492                   Threading Experts
# 14538 -79.340498              District 28 Bar Bistro
# 14539 -79.277202           Kairali - Taste of Kerala
#
#                         neighborhood postal_code  review_count  stars state  \
# 0                     Dufferin Grove     M6H 1L5             7    2.5    ON
# 1                      Downtown Core     M5B 2C2             8    3.0    ON
# 2                    Ossington Strip     M6J 1H1             5    2.0    ON
# 3                      Downtown Core     M5J 2M2            68    3.5    ON
# 4                        Leslieville     M4L 1E9             4    4.5    ON
# 5                          The Beach     M4L 1J3             4    1.5    ON
# 6                        Scarborough     M1V 4C3           118    3.5    ON
# 7                       Harbourfront         M5J             9    3.5    ON
# 8                Yonge and St. Clair     M4T 2S9             5    3.0    ON
# 9                    West Queen West     M6J 1H7            15    2.0    ON
# 10                                       M4N 3M5            18    1.5    ON
# 11                                       M6N 3P1             3    4.5    ON
# 12                        Willowdale     M2N 5S3            41    3.0    ON
# 13                         Yorkville     M4W 1A5            10    3.0    ON
# 14                                       M5S 1Y6             5    3.5    ON
# 15                        Willowdale     M2N 6K7            73    3.0    ON
# 16                      Roncesvalles     M6R 2L6            10    3.0    ON
# 17                                       M3J 2P1             3    3.5    ON
# 18                         Yorkville     M5S 2X9             5    4.0    ON
# 19                                           M6C             8    4.5    ON
# 20                                       M5V 1B8             3    4.5    ON
# 21                           Niagara     M6J 1C1            18    4.5    ON
# 22                       Scarborough     M1X 0B1             3    2.5    ON
# 23                          Rosedale     M4W 2L2            22    3.0    ON
# 24                   West Queen West     M6J 1J6            17    3.5    ON
# 25                         The Beach     M4E 1G2             3    3.5    ON
# 26                       Scarborough         M1R            18    3.0    ON
# 27                         Yorkville     M5R 1P9             3    3.5    ON
# 28                         Chinatown     M5T 2G4           101    3.5    ON
# 29                       Scarborough     M1X 0A4            14    3.0    ON
# ...                              ...         ...           ...    ...   ...
# 14510                      Yorkville     M5R 3V6            80    3.5    ON
# 14511                                    M4L 1Z8            16    4.5    ON
# 14512             Discovery District     M5S 1M1            12    4.0    ON
# 14513                        Niagara     M5V 1C9            59    4.0    ON
# 14514                                    M4K 2P7            16    4.0    ON
# 14515                    Scarborough     M1B 4Y7             4    5.0    ON
# 14516                 Alexandra Park         M5V             5    2.5    ON
# 14517                      High Park     M6R 2K9             9    3.5    ON
# 14518                      Riverdale     M4K 1N2             7    4.5    ON
# 14519            Distillery District         M5A             6    4.0    ON
# 14520                  Downtown Core     M4Y 2G8             4    3.0    ON
# 14521                                    M5M 4A5             3    2.5    ON
# 14522                 Alexandra Park     M5V 2B3            21    3.5    ON
# 14523                  Downtown Core     M4Y 2A6             8    2.5    ON
# 14524                     Willowdale     M2N 5N2            60    3.0    ON
# 14525  Mount Pleasant and Davisville     M4P 2E6             3    3.5    ON
# 14526                    Scarborough     M1P 2L1            17    3.5    ON
# 14527                      The Beach     M4L 3V2             6    4.5    ON
# 14528         Entertainment District     M5V 0M2            14    5.0    ON
# 14529                    Leslieville     M4M 1J3            62    3.0    ON
# 14530         Entertainment District     M5H 1Y2             6    5.0    ON
# 14531  Mount Pleasant and Davisville     M4S 1X8            26    3.5    ON
# 14532                 Alexandra Park         M5V            20    2.5    ON
# 14533                   The Danforth     M4J 1M9           118    4.0    ON
# 14534  Mount Pleasant and Davisville     M4P 2Y1             3    3.5    ON
# 14535                                    M6S 4A5             6    4.5    ON
# 14536                  Downtown Core     M5L 1G5             4    3.0    ON
# 14537                                    M5T 1S7            55    4.5    ON
# 14538                    Leslieville     M4M 2M8             5    2.5    ON
# 14539                    Scarborough     M1P 2L1            19    4.0    ON
#
#            type
# 0      business
# 1      business
# 2      business
# 3      business
# 4      business
# 5      business
# 6      business
# 7      business
# 8      business
# 9      business
# 10     business
# 11     business
# 12     business
# 13     business
# 14     business
# 15     business
# 16     business
# 17     business
# 18     business
# 19     business
# 20     business
# 21     business
# 22     business
# 23     business
# 24     business
# 25     business
# 26     business
# 27     business
# 28     business
# 29     business
# ...         ...
# 14510  business
# 14511  business
# 14512  business
# 14513  business
# 14514  business
# 14515  business
# 14516  business
# 14517  business
# 14518  business
# 14519  business
# 14520  business
# 14521  business
# 14522  business
# 14523  business
# 14524  business
# 14525  business
# 14526  business
# 14527  business
# 14528  business
# 14529  business
# 14530  business
# 14531  business
# 14532  business
# 14533  business
# 14534  business
# 14535  business
# 14536  business
# 14537  business
# 14538  business
# 14539  business
#
# [14540 rows x 16 columns]

# %%
toronto.describe().toPandas()
# Out:
#   summary      address             business_id     city             is_open  \
# 0   count        14540                   14540    14540               14540
# 1    mean         None                    None     None  0.8013755158184319
# 2  stddev         None                    None     None  0.3989783784282531
# 3     min               --DaPTJW3-tB1vP-PfdTEg  Toronto                   0
# 4     max  canada wide  zzf3RkMI1Y2E1QaZqeU8yA  Toronto                   1
#
#               latitude            longitude                name neighborhood  \
# 0                14540                14540               14540        14540
# 1    43.67621023983338   -79.39420013944437              2316.0         None
# 2  0.04313786728158043  0.06192799494269718  1009.7484835343898         None
# 3         43.116234868            -79.70339           00 Gelato
# 4            45.028731           -76.364179              z-teca    Yorkville
#
#   postal_code        review_count               stars  state      type
# 0       14540               14540               14540  14540     14540
# 1        None  24.050550206327372  3.5157496561210455   None      None
# 2        None   47.23432101358981   0.871000467081536   None      None
# 3                               3                 1.0     ON  business
# 4     W8M 3T5                1145                 5.0     ON  business

# %%
df_business.take(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-eec8d4854d52> in <module>()
# ----> 1 df_business.take(1)
#
# NameError: name 'df_business' is not defined

# %% [markdown]
# ### Choosing a business category
#
# - Define a regular Python function that takes a list of categories and returns 1 if a category of your choice (for instance, 'Restaurants') is contained in the list of categories or 0 otherwise
# - Using the Python function, define a Spark's User Defined Function (UDF) with an IntegerType return
# - Using the UDF, filter the businesses that belong to the category you chose

# %%
from pyspark.sql.functions import UserDefinedFunction
from pyspark.sql.types import IntegerType, BooleanType
from pyspark.sql.functions import UserDefinedFunction
from pyspark.ml.linalg import VectorUDT, Vectors

                             
def is_italian(categories):
    return "Italian" in categories if categories else False 

is_it_udf = UserDefinedFunction(is_italian, BooleanType())

df_italians_toronto = toronto.filter(is_it_udf("categories"))

# %%
df_italians_toronto
# Out:
# DataFrame[address: string, attributes: array<string>, business_id: string, categories: array<string>, city: string, hours: array<string>, is_open: bigint, latitude: double, longitude: double, name: string, neighborhood: string, postal_code: string, review_count: bigint, stars: double, state: string, type: string]

# %% [markdown]
# ### Choosing a city
# - Having filtered by the business category, now it is time to filter by the city (for instance, Edinburgh)

# %% [markdown]
# ### Generating numeric IDs
# - If you haven't done it yet, take one sample from your already filtered DataFrame and notice that the ***business_id*** contains an alphanumeric value - this is not good for Spark's ALS implementation, which requires IDs for items (in our case, businesses) and users to be numeric
# - Use a ***StringIndexer*** to create a new column ***business_idn*** from the conversion of business_id into a numeric value

# %%
from pyspark.ml.feature import StringIndexer

business_indexer = StringIndexer().setInputCol("business_id").setOutputCol("business_idn").setHandleInvalid('skip')
        

df_italians_toronto = business_indexer.fit(df_italians_toronto).transform(df_italians_toronto)

# %%
df_italians_toronto.toPandas()
# Out:
#                             address  \
# 0                979 Bloor Street W
# 1                 2816 Markham Road
# 2            98 Island Road, Unit C
# 3             552 Parliament Street
# 4               2100 Bloor Street W
# 5         1228 Saint Clair Avenue W
# 6                   106 Victoria St
# 7                  1986 Weston Road
# 8                    594 College St
# 9           579 Mount Pleasant Road
# 10                    41 Clinton St
# 11                207 Queens Quay W
# 12               646 Queen Street W
# 13                93 Front Street E
# 14               188 Augusta Avenue
# 15                 1 Romar Crescent
# 16                791 King Street W
# 17         1501 Gerrard Street East
# 18                10 Clinton Street
# 19               583 College Street
# 20              297 Port Union Road
# 21   3401 Dufferin Street, Unit R04
# 22              4 Temperance Street
# 23           38 Wellington Street E
# 24                  1419 Bloor St W
# 25                2059 Yonge Street
# 26              2343 Queen Street E
# 27              1056 Queen Street E
# 28               901 Bloor Street W
# 29           672 St. Clair Avenue W
# ..                              ...
# 475              10 Dundas Street E
# 476                95 King Street E
# 477                73 King Street E
# 478            148 Yorkville Avenue
# 479  171 E Liberty Village, Unit135
# 480              898 Queen Street E
# 481              1561 The Queensway
# 482              259 Queen Street W
# 483              1338 Lansdowne Ave
# 484           2777 Steeles Avenue W
# 485                  665 College St
# 486                 244 Jane Street
# 487         335 Roncesvalles Avenue
# 488               663 King Street W
# 489                 113 Bond Street
# 490     2083 Lake Shore Boulevard W
# 491                 2982 Bloor St W
# 492                603 Yonge Street
# 493               2088 Yonge Street
# 494                116A Avenue Road
# 495               1997 Yonge Street
# 496                  736 Bay Street
# 497             1165 Queen Street W
# 498                   1993 Yonge St
# 499  382 Spadina Avenue, Main Floor
# 500                35 Church Street
# 501              2171 Steeles Ave W
# 502                  995 Bay Street
# 503              596 College Street
# 504                2015 Avenue Road
#
#                                             attributes  \
# 0    [Alcohol: none, Ambience: {'romantic': False, ...
# 1    [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 2    [BusinessAcceptsCreditCards: True, BusinessPar...
# 3    [Alcohol: none, Ambience: {'romantic': False, ...
# 4    [Alcohol: beer_and_wine, BusinessParking: {'ga...
# 5    [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 6    [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 7    [BusinessAcceptsCreditCards: True, GoodForKids...
# 8    [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 9    [Alcohol: full_bar, Ambience: {'romantic': Tru...
# 10   [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 11   [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 12   [Alcohol: beer_and_wine, Ambience: {'romantic'...
# 13   [Alcohol: none, Ambience: {'romantic': False, ...
# 14   [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 15   [GoodForMeal: {'dessert': False, 'latenight': ...
# 16   [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 17   [BikeParking: True, GoodForKids: True, GoodFor...
# 18   [Alcohol: none, Ambience: {'romantic': False, ...
# 19   [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 20   [Alcohol: none, BusinessAcceptsCreditCards: Tr...
# 21   [Alcohol: beer_and_wine, Ambience: {'romantic'...
# 22   [Alcohol: beer_and_wine, Ambience: {'romantic'...
# 23   [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 24   [Alcohol: none, Ambience: {'romantic': False, ...
# 25   [Alcohol: beer_and_wine, Ambience: {'romantic'...
# 26   [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 27   [Alcohol: none, Ambience: {'romantic': False, ...
# 28   [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 29   [Alcohol: beer_and_wine, Ambience: {'romantic'...
# ..                                                 ...
# 475  [BusinessAcceptsCreditCards: True, GoodForKids...
# 476  [Alcohol: none, Ambience: {'romantic': False, ...
# 477  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 478  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 479  [Alcohol: none, Ambience: {'romantic': False, ...
# 480  [Alcohol: none, Ambience: {'romantic': False, ...
# 481  [GoodForKids: True, RestaurantsDelivery: True,...
# 482  [Alcohol: beer_and_wine, Ambience: {'romantic'...
# 483  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 484  [Alcohol: full_bar, BusinessAcceptsCreditCards...
# 485  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 486  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 487  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 488  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 489  [Alcohol: none, Ambience: {'romantic': False, ...
# 490  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 491  [BusinessAcceptsCreditCards: True, BusinessPar...
# 492  [Alcohol: full_bar, BikeParking: True, Busines...
# 493  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 494  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 495  [Alcohol: none, BikeParking: True, BusinessAcc...
# 496  [Alcohol: none, Ambience: {'romantic': False, ...
# 497  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 498  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 499  [Alcohol: beer_and_wine, Ambience: {'romantic'...
# 500  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 501  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 502  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 503  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 504  [Alcohol: full_bar, Ambience: {'romantic': Fal...
#
#                 business_id  \
# 0    EDqCEAGXVGCH4FJXgqtjqg
# 1    L_thK7r3K_h5M4tV7amEKQ
# 2    VutzmcU-hZt_WfgMkEuiFA
# 3    nPBZaN5ttrArS6tZwdjN7Q
# 4    6tFbsJuIarw6vawDOZ9GkA
# 21      M6A 3A1            29    3.5    ON  business         140.0
# 22      M5H 1Y4           128    3.5    ON  business         127.0
# 23      M5E 1C7            29    4.0    ON  business          82.0
# 24      M6P 3L4            11    4.0    ON  business           9.0
# 25      M4S 2A2            51    4.0    ON  business         388.0
# 26      M4E 1H2            23    4.0    ON  business         112.0
# 27      M4M 1K3             7    2.0    ON  business          35.0
# 28      M6H 1L2            10    3.0    ON  business          72.0
# 29      M6C 1A9            22    3.5    ON  business         384.0
# ..          ...           ...    ...   ...       ...           ...
# 475         M5B             3    4.0    ON  business         187.0
# 476         M5C            11    3.5    ON  business         155.0
# 477     M5C 3J6            73    4.5    ON  business         218.0
# 478     M5R 1C2            11    3.5    ON  business         379.0
# 479     M6K 3P6             7    3.0    ON  business         250.0
# 480     M4M 1J3           362    4.0    ON  business         253.0
# 481     M8Z 1T8             3    3.0    ON  business         453.0
# 482     M5V 1Z4             6    3.5    ON  business         476.0
# 483     M6H 3Z8            31    3.0    ON  business         162.0
# 484     M3J 3K5            15    3.0    ON  business          60.0
# 485     M6G 1B7            57    3.5    ON  business         346.0
# 486     M6S 3Y8            25    4.5    ON  business         276.0
# 487     M6R 2M8            11    3.0    ON  business         401.0
# 488     M5V 1M5            51    3.5    ON  business         470.0
# 489     M5B 1Y2            12    4.5    ON  business         223.0
# 490     M8V 1A1            17    4.0    ON  business          67.0
# 491     M8X 1B9             6    3.0    ON  business         185.0
# 492     M4Y 1Z5           131    3.5    ON  business         496.0
# 493     M4S 2A3            77    4.0    ON  business         367.0
# 494     M5R 2H4            65    4.0    ON  business          31.0
# 495     M4S 1Z8            16    5.0    ON  business         300.0
# 496     M5G 2M4            12    3.0    ON  business         166.0
# 497     M6J 1J6            69    3.5    ON  business         100.0
# 498     M4S 1Z8            30    3.5    ON  business         373.0
# 499     M5T 2G5            68    4.5    ON  business         120.0
# 500     M5E 1T3           231    3.5    ON  business         338.0
# 501     M3J 3N2            29    1.5    ON  business         174.0
# 502     M5S 3A6            12    2.0    ON  business         287.0
# 503     M6G 1B4             3    4.0    ON  business         494.0
# 504     M5M 4A5             3    2.5    ON  business         246.0
#
# [505 rows x 17 columns]

# %% [markdown]
# ## Review Data
#
# - Load the file ***yelp_academic_dataset_review.json*** and select the following columns:
#     - user_id
#     - business-id
#     - stars
#     - date

# %%
df_reviews = sqlc.read.json("/media/diego/QData/datasets/yelp_dsr/yelp_academic_dataset_review.json")

# %%
df_reviews = df_reviews.withColumnRenamed('stars','stars_r').withColumnRenamed('type','type_r')

# %% [markdown]
# ### Keeping reviews for the chosen city only
#
# - You are only interested in reviews of businesses you kept after filtering for category and city - how to filter out everything else? (hint: take a look at the ***join*** operation of DataFrames)

# %%
df_city_reviews = df_italians_toronto.join(df_reviews, on='business_id')

# %%
df_city_reviews
# Out:
# DataFrame[business_id: string, address: string, attributes: array<string>, categories: array<string>, city: string, hours: array<string>, is_open: bigint, latitude: double, longitude: double, name: string, neighborhood: string, postal_code: string, review_count: bigint, stars: double, state: string, type: string, business_idn: double, cool: bigint, date: string, funny: bigint, review_id: string, stars_r: bigint, text: string, type_r: string, useful: bigint, user_id: string]

# %%
df_city_reviews.write.json(path="data/city_reviews")

# %% [markdown]
# ### Generating numeric IDs
#
# - As it happened with the ***business_id***, you also need to convert ***user_id*** into a numeric value - once again, use a ***StringIndexer*** to create a new column named ***user_idn*** containing the result of the conversion

# %%
from pyspark.ml.feature import StringIndexer

business_indexer = StringIndexer().setInputCol("user_id").setOutputCol("user_idn").setHandleInvalid('skip')
        

df_city_reviews = business_indexer.fit(df_city_reviews).transform(df_city_reviews)

# %%
df_city_reviews.cache()
# Out:
# DataFrame[business_id: string, address: string, attributes: array<string>, categories: array<string>, city: string, hours: array<string>, is_open: bigint, latitude: double, longitude: double, name: string, neighborhood: string, postal_code: string, review_count: bigint, stars: double, state: string, type: string, business_idn: double, cool: bigint, date: string, funny: bigint, review_id: string, stars_r: bigint, text: string, type_r: string, useful: bigint, user_id: string, user_idn: double]

# %% [markdown]
# ### Adding a sequential number to the user's reviews
#
# - Now add a ***sequential number*** to the user's reviews, that is, for each user, order his/her reviews by date (multiple reviews on the same date can be randomly ordered) and number them (hint: check ***window functions***)
# - This sequential number will be useful later to perform a time-wise split of the dataset

# %%
from pyspark.sql import functions as F
from pyspark.sql import Window
from pyspark.sql.functions import count

windowSpec = Window.partitionBy(df_city_reviews['user_idn']).orderBy(df_city_reviews['date']) 
    
df_review_cnt = df_city_reviews.select("user_idn", count("date").over(windowSpec).alias("count"))

# %%
df_review_cnt.show(10)
# Out:
# +--------+-----+
# |user_idn|count|
# +--------+-----+
# |   299.0|    1|
# |   299.0|    2|
# |   299.0|    3|
# |   299.0|    4|
# |   299.0|    5|
# |   299.0|    6|
# |   299.0|    7|
# |   305.0|    1|
# |   305.0|    2|
# |   305.0|    3|
# +--------+-----+
# only showing top 10 rows

# %%
df_city_reviews = df_city_reviews.join(df_review_cnt, on='user_idn')

# %%
# Out:
#    user_idn             business_id              address  \
# 0    2197.0  Dnq4w6ajMifZFFTIR5cGxw  1151 Davenport Road
# 1    2197.0  Dnq4w6ajMifZFFTIR5cGxw  1151 Davenport Road
# 2   10243.0  Dnq4w6ajMifZFFTIR5cGxw  1151 Davenport Road
# 3    5768.0  Dnq4w6ajMifZFFTIR5cGxw  1151 Davenport Road
# 4   11731.0  Dnq4w6ajMifZFFTIR5cGxw  1151 Davenport Road
#
#                                           attributes  \
# 0  [Alcohol: none, Ambience: {'romantic': False, ...
# 1  [Alcohol: none, Ambience: {'romantic': False, ...
# 2  [Alcohol: none, Ambience: {'romantic': False, ...
# 3  [Alcohol: none, Ambience: {'romantic': False, ...
# 4  [Alcohol: none, Ambience: {'romantic': False, ...
#
#                                   categories     city  \
# 0  [Italian, Restaurants, Pizza, Sandwiches]  Toronto
# 1  [Italian, Restaurants, Pizza, Sandwiches]  Toronto
# 2  [Italian, Restaurants, Pizza, Sandwiches]  Toronto
# 3  [Italian, Restaurants, Pizza, Sandwiches]  Toronto
# 4  [Italian, Restaurants, Pizza, Sandwiches]  Toronto
#
#                                                hours  is_open   latitude  \
# 0  [Tuesday 11:0-21:0, Wednesday 11:0-21:0, Thurs...        1  43.674561
# 1  [Tuesday 11:0-21:0, Wednesday 11:0-21:0, Thurs...        1  43.674561
# 2  [Tuesday 11:0-21:0, Wednesday 11:0-21:0, Thurs...        1  43.674561
# 3  [Tuesday 11:0-21:0, Wednesday 11:0-21:0, Thurs...        1  43.674561
# 4  [Tuesday 11:0-21:0, Wednesday 11:0-21:0, Thurs...        1  43.674561
#
#    longitude  ...  cool        date funny               review_id  stars_r  \
# 0 -79.431663  ...     0  2017-01-07     0  Ioko8qRban3R-o3NB3AOeQ        5
# 1 -79.431663  ...     0  2017-01-07     0  Ioko8qRban3R-o3NB3AOeQ        5
# 2 -79.431663  ...     0  2016-12-23     0  KAM3yMErPwHX5BKywUYyOA        5
# 3 -79.431663  ...     0  2016-10-11     0  1AvYCkFn5gz2qk5PA6GJWw        5
# 4 -79.431663  ...     0  2016-01-15     0  AowSoAsbT-VE8y27ejtaTg        5
#
#                                                 text  type_r  useful  \
# 0  hands down the best sausage ive ever had. it c...  review       0
# 1  hands down the best sausage ive ever had. it c...  review       0
# 2  Amazing one of the best pork belly sandwiches ...  review       0
# 3  Dante's Inferno is without question (in my hum...  review       1
# 4  I'm so pleased to say that Dante's Inferno Pan...  review       0
#
#                   user_id count
# 0  w7QSVBgCYHu2_MG6w6Jp7Q     2
# 1  w7QSVBgCYHu2_MG6w6Jp7Q     1
# 2  195i7Ix1PruGaz9SsOi6Iw     1
# 3  -onI--GpQ__P1ibxx25MRA     1
# 4  sQeSycJd1EI4QafGOsloqQ     1
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Subsetting reviews to keep only users with more than 4 reviews
#
# - Some users had rated only 1 or a few businesses - this would pose as a problem to make recommendations - so you would want to keep only users who had rated more than 4 reviews, for instance
# - Find the ***total number of reviews*** for each user and then filter them using this information (hint: again, you can use a ***window function***)

# %%
from pyspark.sql import functions as F
from pyspark.sql import Window
from pyspark.sql.functions import count, sys

windowSpec = Window.partitionBy(df_city_reviews['user_idn']).orderBy(df_city_reviews['date']).rowsBetween(-sys.maxsize, sys.maxsize)
    
df_review_sum = df_city_reviews.select("user_idn", count('date').over(windowSpec).alias("count_tot"))

df_review_sum.show(10)
# Out:
# +--------+-----+
# |user_idn|sum_r|
# +--------+-----+
# |   299.0|   49|
# |   299.0|   49|
# |   299.0|   49|
# |   299.0|   49|
# |   299.0|   49|
# |   299.0|   49|
# |   299.0|   49|
# |   299.0|   49|
# |   299.0|   49|
# |   299.0|   49|
# +--------+-----+
# only showing top 10 rows

# %%
df_city_reviews = df_city_reviews.join(df_review_sum, on='user_idn')

# %%
df_city_reviews.toPandas().head()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-56-e36ae760dec6> in <module>()
# ----> 1 df_city_reviews.toPandas().head()
#
# ~/anaconda3/envs/spark/lib/python3.6/site-packages/pyspark/sql/dataframe.py in toPandas(self)
#    1701         """
#    1702         import pandas as pd
# -> 1703         return pd.DataFrame.from_records(self.collect(), columns=self.columns)
#    1704
#    1705     ##########################################################################################
#
# ~/anaconda3/envs/spark/lib/python3.6/site-packages/pyspark/sql/dataframe.py in collect(self)
#     436         """
#     437         with SCCallSiteSync(self._sc) as css:
# --> 438             port = self._jdf.collectToPython()
#     439         return list(_load_from_socket(port, BatchedSerializer(PickleSerializer())))
#     440
#
# ~/anaconda3/envs/spark/lib/python3.6/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1158         answer = self.gateway_client.send_command(command)
#    1159         return_value = get_return_value(
# -> 1160             answer, self.gateway_client, self.target_id, self.name)
#    1161
#    1162         for temp_arg in temp_args:
#
# ~/anaconda3/envs/spark/lib/python3.6/site-packages/pyspark/sql/utils.py in deco(*a, **kw)
#      61     def deco(*a, **kw):
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#      65             s = e.java_exception.toString()
#
# ~/anaconda3/envs/spark/lib/python3.6/site-packages/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     318                 raise Py4JJavaError(
#     319                     "An error occurred while calling {0}{1}{2}.\n".
# --> 320                     format(target_id, ".", name), value)
#     321             else:
#     322                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling o536.collectToPython.
# : java.lang.OutOfMemoryError: Java heap space
# 	at org.apache.spark.sql.execution.SparkPlan$$anon$1.next(SparkPlan.scala:261)
# 	at org.apache.spark.sql.execution.SparkPlan$$anon$1.next(SparkPlan.scala:257)
# 	at scala.collection.Iterator$class.foreach(Iterator.scala:893)
# 	at org.apache.spark.sql.execution.SparkPlan$$anon$1.foreach(SparkPlan.scala:257)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeCollect$1.apply(SparkPlan.scala:279)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeCollect$1.apply(SparkPlan.scala:278)
# 	at scala.collection.IndexedSeqOptimized$class.foreach(IndexedSeqOptimized.scala:33)
# 	at scala.collection.mutable.ArrayOps$ofRef.foreach(ArrayOps.scala:186)
# 	at org.apache.spark.sql.execution.SparkPlan.executeCollect(SparkPlan.scala:278)
# 	at org.apache.spark.sql.Dataset$$anonfun$collectToPython$1.apply$mcI$sp(Dataset.scala:2803)
# 	at org.apache.spark.sql.Dataset$$anonfun$collectToPython$1.apply(Dataset.scala:2800)
# 	at org.apache.spark.sql.Dataset$$anonfun$collectToPython$1.apply(Dataset.scala:2800)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:65)
# 	at org.apache.spark.sql.Dataset.withNewExecutionId(Dataset.scala:2823)
# 	at org.apache.spark.sql.Dataset.collectToPython(Dataset.scala:2800)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:280)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:214)
# 	at java.lang.Thread.run(Thread.java:748)

# %%
df_city_reviews.cache()

# %% [markdown]
# ### Calculating mean rating by user
#
# - Now you can calculate the mean rating by user and make it into a dictionary where the key is the ***user_id*** (hint: look at ***rdd*** method of DataFrames and ***collectAsMap*** method of RDDs)

# %%
dict_user_means = ...

# %% [markdown]
# ### Centering rating by user
#
# - The dictionary containing mean ratings by user can be seen as a ***lookup table*** - what is the appropriate way of dealing with those in Spark?
# - Once you have figured this out, define a regular Python function that takes two arguments - ***user_id*** (String) and ***rating*** (String, which you will need to convert to float inside the function) - and returns the result of subtracting the mean rating of the user from the rating parameter
# - Using the Python function, define a Spark's User Defined Function (UDF) with a DoubleType return
# - Using the UDF, create a column in your DataFrame with the centered ratings
#     - Notice that your UDF needs two columns as input: ***user_id*** and ***stars*** - so far, all UDFs received only one column (hint: check the ***array*** function from pyspark.sql)

# %%
from pyspark.sql.functions import array

lookup_user_means = ...

def zero_mean(user_id, rating):
    pass

df_centered = ...

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Splitting into training and test sets by time
#
# - In recommender systems, it is common practice to do the training/test split timewise, that is, the test set is composed of the latest reviews
# - First, filter only those reviews which have a sequential number smaller than the ***total number of reviews***, by user: this is your training set
# - Then, filter only those reviews which have a sequential number identical to the ***total number of reviews***, by user: this is your test set
# - Now you can see why you had to add the random time to the review's date - since some users had done all his/her reviews on the same day, your training set for that particular use would have been empty. By doing this, you guarantee your test set will have only 1 review for each user.

# %%
df_training = ...
df_test = ...

# %% [markdown]
# ## Alternate Least Squares (ALS) Model
#
# - This is the recommender itself - the ALS uses a iterative approach to find the underlying factors that yield the user/item rating matrix
# - It takes as input a DataFrame with three columns, representing:
#     - userCol: user IDs (numeric - remember the conversion you did)
#     - itemCol: item IDs (numeric - remember the conversion you did)
#     - ratingCol: rating (numeric, obviously)
#     - coldStartStrategy: "drop" (if there is unseen data on the test set, meaning a new user, drop it)
# - Its parameters are:
#     - rank: the number of factors to consider
#     - maxIter: the maximum number of iterations to perform
#     - regParam: the regularization parameter
# - Use Spark's ALS to fit a model based on your DataFrame

# %%
from pyspark.ml.recommendation import ALS
from pyspark.ml.evaluation import RegressionEvaluator

model = ...

# %% [markdown]
# ### Predictions for the training set
#
# - Once the model is trained, make predictions for the training set and use a ***RegressionEvaluator*** to find out the RMSE of the predictions

# %%
predictions = ...

evaluator = ...

train_rmse = ...

print(train_rmse)

# %% [markdown]
# ### Predictions for the test set
#
# - Now, make predictions for the test set and use a ***RegressionEvaluator*** to find out the RMSE of the predictions

# %%
...

print(test_rmse)

# %% [markdown]
# ## Recommendations
#
# Now, your model is trained, but how can you use it to make recommendations for a given user?

# %% [markdown]
# ### Organizing business data
#
# - It would not make sense to recommend a place the user has already rated, right? So, generate a dictionary where ***user_idn*** is the key and a list of the already rated ***business_idn*** is the value (hint: when aggregating DataFrames, ***collect_list*** is a VERY useful function to turn multiple records into a list)

# %%
from pyspark.sql.functions import collect_list

dict_visited_by_user = ...

# %% [markdown]
# - Besides, recommending a given business_id also does not help much, right? So you need to organize the business data in a way it can be shown to the user.
#     - Define a regular Python function that takes one argument ***row*** (Row type) and returns a dictionary where ***business_idn*** is the key and the value is yet another dictionary with relevant fields (for instance: name, address, stars, categories)
#     - Transform your business DataFrame into an RDD and apply the function you defined - upon collecting, you will end up with a list of dictionaries
#     - Transform this list of dictionaries into a single dictionary

# %%
def rest_to_json(row):
    pass

rest = ...

dict_rest = {k: v for d in rest for k, v in d.items()}

# %% [markdown]
# ### Making recommendations for a user
#
# - To actually make the recommendations, we need to build an input DataFrame to feed the model
#     - A DataFrame can be created using the SQL Context and a list of Rows, each containg two columns: user_idn and business_idn - the rating will be computed by the model
#     - But you only need to have rows for the businesses which were not yet rated by the user - from all businesses, exclude the ones already rated by him/her

# %%
from pyspark.sql import Row
from pyspark.sql.functions import desc

user_idn = 317
n_business = len(dict_rest)

visited = ...
not_visited = ...

df_test_user = ...

# %% [markdown]
# - Now, you can use the generated DataFrame to make predictions
#     - If there are any NA predictions, make sure to turn them into a really bad value (for instance, -5.0) (hint: remember ***na*** method of DataFrames)
# - Order the predictions and take the ***business_idn*** of the top 5
# - Finally, use this information to fetch the business data from the dictionary you assembled a couple of steps ago

# %%
predictions = ...

top_predictions = ...

response = list(map(lambda idn: dict_rest[idn], top_predictions))

# %%
response

# %% [markdown]
# ## Congratulations, you finished the exercise!

# %%
sc.stop()
